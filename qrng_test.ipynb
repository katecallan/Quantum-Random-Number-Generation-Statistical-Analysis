# %%
import pandas as pd
import numpy as np

df = pd.read_csv("numbers_all.csv")
print(f"Loaded {len(df)} numbers")
print(df.describe())
print(f"\nMin: {df['random_number'].min()}, Max: {df['random_number'].max()}")
# Out:
# Loaded 9870 numbers
#        random_number
# count    9870.000000
# mean    32656.213273
# std     19001.532992
# min         4.000000
# 25%     15773.750000
# 50%     32577.500000
# 75%     48937.000000
# max     65533.000000
#
# Min: 4, Max: 65533
